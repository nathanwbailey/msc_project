# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from torch.utils.data import Dataset
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import random
import torch.nn.functional as F
from torchmetrics.functional.image.ssim import (
    structural_similarity_index_measure,
)
from torchmetrics.functional.image.psnr import peak_signal_noise_ratio

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
random.seed(42)
g = torch.Generator()
g.manual_seed(42)

# %%
def resize_encoder(sample):
    sample = sample.unsqueeze(0)
    sample = F.interpolate(
        sample, size=(144, 72), mode="bicubic", align_corners=False
    )
    return sample.squeeze(0)


def random_mask(sample, mask_prob_low=0.7, mask_prob_high=0.7):
    if mask_prob_low == mask_prob_high:
        mask_prob = mask_prob_low
    else:
        mask_prob = random.uniform(mask_prob_low, mask_prob_high)
    random_tensor = torch.rand(sample.shape, device=sample.device)
    mask = (random_tensor > mask_prob).float()
    masked_image = sample * mask
    return masked_image


class WeatherBenchDataset(Dataset):
    def __init__(self, data, mask_prob_low=0.7, mask_prob_high=0.7):
        self.data = data
        self.mask_prob_low = mask_prob_low
        self.mask_prob_high = mask_prob_high

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):
        X = self.data[idx]
        X_enc = resize_encoder(X)
        X_masked = random_mask(
            X_enc,
            mask_prob_low=self.mask_prob_low,
            mask_prob_high=self.mask_prob_high,
        )
        return X, X_masked

# %%
# See: https://arxiv.org/pdf/2407.15171
def gaussian_density(z_g, Z, sigma):
    z_g = z_g.float()
    Z = Z.float()

    if z_g.dim() == 1:
        z_g = z_g.unsqueeze(0)
        squeeze_out = True
    else:
        squeeze_out = False

    # Compute squared Euclidean distances:
    #   diff: (B, N, d)
    #   sq_dist: (B, N)
    diff = Z.unsqueeze(0) - z_g.unsqueeze(1)
    sq_dist = (diff**2).sum(dim=-1)

    weights = torch.exp(-sq_dist / (2 * sigma**2))
    D = weights.mean(dim=-1)

    return D.squeeze(0) if squeeze_out else D

# %%
# Realism Score
# https://arxiv.org/pdf/1904.06991
def realism_score(real_feats, gen_feats, k):
    N_r, D = real_feats.shape
    # Distance for nearest neighbours
    dist_rr = torch.cdist(real_feats, real_feats)
    # ignore self‐distance
    idx = torch.arange(N_r, device=real_feats.device)
    dist_rr[idx, idx] = float("inf")
    r_k = dist_rr.kthvalue(k, dim=1)
    dist_gr = torch.cdist(gen_feats, real_feats)  # (N_g, N_r)
    # Realism matrix
    ratios = r_k.unsqueeze(0) / dist_gr  # (N_g, N_r)
    # Max over reals
    realism = ratios.max(dim=1)
    return realism

# %%
def plot_image(xh, x_full):
    num_channels = xh.shape[0]
    _, axes = plt.subplots(2, num_channels, figsize=(4 * num_channels, 4))
    mode_labels = [
        "2m_temperature",
        "u_component_of_wind",
        "v_component_of_wind",
        "geopotential",
        "specific_humidity",
    ]
    for i in range(num_channels):
        ax = axes[0, i]
        ax.imshow(x_full[i], cmap="coolwarm")
        ax.set_title(mode_labels[i])
        ax.axis("off")
    for i in range(num_channels):
        ax = axes[1, i]
        ax.imshow(xh[i], cmap="coolwarm")
        ax.set_title(mode_labels[i])
        ax.axis("off")
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
latent_model = torch.load(
    "conditional_latent_model.pth", weights_only=False, map_location=DEVICE
)
model = torch.load(
    "simclr_decoder_freeze.pth", weights_only=False, map_location=DEVICE
)
latent_model.eval()
model.eval()

encoder_model = model.model
decoder_model = model.decoder

data = torch.load("/vol/bitbucket/nb324/ERA5_64x32_daily_850.pt")
n_samples = data.shape[0]
n_train = int(n_samples * 0.6)
n_valid = int(n_samples * 0.2)
data = data[n_train + n_valid :]


BATCH_SIZE = 128
NUM_TIMES_TO_SAMPLE = 10
n_samples = data.shape[0]

n_train = int(n_samples * 0.6)
n_valid = int(n_samples * 0.2)

train_data = data[:n_train]
valid_data = data[n_train : n_train + n_valid]
test_data = data[n_train + n_valid :]

mean = train_data.mean(dim=(0, 2, 3), keepdim=True)
std = train_data.std(dim=(0, 2, 3), keepdim=True)

test_data = (test_data - mean) / std

# %%
test_dataset = WeatherBenchDataset(
    data=test_data, mask_prob_low=0.7, mask_prob_high=0.7
)
testloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# Encode the data

encoded_data = []
with torch.no_grad():
    for data in testloader:
        x_mask = data[1].to(DEVICE)
        x_mask_enc = encoder_model.encode(x_mask)
        encoded_data.append(x_mask_enc)

encoded_data = torch.cat(encoded_data, dim=0)

# %%
# Generate some samples
batch = random.choice(list(testloader))
condition = batch[1].to(DEVICE)
condition = encoder_model.encode(condition)

# Take the average generated image
zh_sum = torch.zeros(condition.shape[0], 1000).to(DEVICE)
for i in range(NUM_TIMES_TO_SAMPLE):
    with torch.no_grad():
        zh = latent_model.sample(condition.shape[0], 1000, condition)
    zh_sum += zh
zh_mean = zh_sum / NUM_TIMES_TO_SAMPLE

# Compute gaussian density score
gaussian_density_score = gaussian_density(z_g=zh_mean, Z=encoded_data, sigma=20.0)
gaussian_density_score = gaussian_density_score.mean()
print(f"Gaussian Density Score: {gaussian_density_score.item()}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       8 for i in range(NUM_TIMES_TO_SAMPLE):
#       9     with torch.no_grad():
# ---> 10         zh = latent_model.sample(condition.shape[0], 1000, condition)
#      11     zh_sum += zh
#      12 zh_mean = zh_sum / NUM_TIMES_TO_SAMPLE
#
# File ~/Documents/masters_project_multi_modal/latent_diffusion_model_conditional_attn/ddpm.py:55, in DDPM.sample(self, n_sample, size, condition, t)
#      48         rand_noise = torch.zeros_like(x_i)
#      49     rand_noise = rand_noise.to(self.device)
#      50     x_i = (
#      51         self.oneover_sqrta[i]
#      52         * (
#      53             x_i
#      54             - self.mab_over_sqrtmab[i]
# ---> 55             * self.eps_model(x_i, time_tensor, condition)
#      56         )
#      57         + self.sqrt_beta_t[i] * rand_noise
#      58     )
#      60 return x_i
#
# File /vol/bitbucket/nb324/masters_project/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /vol/bitbucket/nb324/masters_project/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/masters_project_multi_modal/latent_diffusion_model_conditional_attn/model.py:167, in LatentNetwork.forward(self, x, time, condition)
#     164     x = layer(x, cond_tokens, time_emb)
#     165     skips.append(x)
# --> 167 x = self.bottleneck(x, cond_tokens_list_enc[-1], time_emb)
#     169 for layer, cond_tokens in zip(self.dec, cond_tokens_list_dec):
#     170     x = torch.cat((x, skips.pop()), dim=1)
#
# File /vol/bitbucket/nb324/masters_project/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1735, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1732             tracing_state.pop_scope()
#    1733     return result
# -> 1735 def _wrapped_call_impl(self, *args, **kwargs):
#    1736     if self._compiled_call_impl is not None:
#    1737         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
# Realism Score
realism_score_val = realism_score(real_feats=encoded_data, gen_feats=zh_mean, k=5)
realism_score_val = realism_score_val.mean()
print(f"Realism Score: {realism_score_val.item()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Realism Score
# ----> 2 realism_score_val = realism_score(real_feats=encoded_data, gen_feats=zh_mean, k=5)
#       3 realism_score_val = realism_score_val.mean()
#       4 print(f"Realism Score: {realism_score_val.item()}")
#
# Cell In[13], line 13, in realism_score(real_feats, gen_feats, k)
#      11 dist_gr = torch.cdist(gen_feats, real_feats)  # (N_g, N_r)
#      12 # Realism matrix
# ---> 13 ratios = r_k.unsqueeze(0) / dist_gr  # (N_g, N_r)
#      14 # Max over reals
#      15 realism = ratios.max(dim=1)
#
# AttributeError: 'torch.return_types.kthvalue' object has no attribute 'unsqueeze'

# %%
zh_mean = zh_mean.to(DEVICE)
with torch.no_grad():
    xh = decoder_model(zh_mean).cpu()
x_f = batch[0].cpu()

# %%
x_f = batch[0].cpu()
mse_loss = F.mse_loss(xh, x_f)

x_min = train_data.amin(dim=(0, 2, 3), keepdim=True)
x_max = train_data.amax(dim=(0, 2, 3), keepdim=True)

decoded_data_ = (xh - x_min) / (x_max - x_min + 1e-8)
output_data_ = (x_f - x_min) / (x_max - x_min + 1e-8)

ssim = structural_similarity_index_measure(decoded_data_, output_data_, data_range=1.0)
psnr = peak_signal_noise_ratio(decoded_data_, output_data_, data_range=1.0)

print(f"MSE Batch Loss: {mse_loss:.4f}")
print(f"SSIM Batch: {ssim}")
print(f"PSNR Batch: {psnr}")
# Out:
# MSE Batch Loss: 7.6816
# SSIM Batch: 0.6060836315155029
# PSNR Batch: -27.79177474975586

# %%
xh = xh[0]
x_f = x_f[0]
mse_loss = F.mse_loss(xh, x_f)
decoded_data_ = (xh - x_min) / (x_max - x_min + 1e-8)
output_data_ = (x_f - x_min) / (x_max - x_min + 1e-8)
ssim = structural_similarity_index_measure(decoded_data_, output_data_, data_range=1.0)
psnr = peak_signal_noise_ratio(decoded_data_, output_data_, data_range=1.0)
xh = xh.numpy()
x_f = x_f.numpy()
plot_image(xh, x_f)
print(f"MSE Loss: {mse_loss:.4f}")
print(f"SSIM Batch: {ssim}")
print(f"PSNR Batch: {psnr}")
# Out:
# MSE Loss: 4.6556
# SSIM Batch: 0.6508685350418091
# PSNR Batch: -25.332496643066406
